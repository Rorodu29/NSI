# %%
from random import *

P_Joueur = 0
C_Joueur = 0

P_Ordi = 0
C_Ordi = 0

for i in range (1, 6):
    
    C_Ordi = randint(1, 3)              
    C_Joueur = input("1 : pierre, 2 : papier, 3 : ciseaux ? ") 
    while C_Joueur == "1" :
        if C_Ordi == 1:
            print("Egalité")
        elif C_Ordi == 2 :
            print("L'ordi a gagné")
            P_Ordi = P_Ordi + 1
        elif C_Ordi == 3 :
            print("Vous avez gagné !")
            print("Bravo !")
            P_Joueur = P_Joueur + 1
        break
        
            
    while C_Joueur == "2" :
        if C_Ordi == 1 :
            print("Vous avez gagné !")
            print("Bravo !")
            P_Joueur = P_Joueur + 1
            
        elif C_Ordi == 2 :
               print("Egalité")
                
        elif C_Ordi == 3 :
            print("L'ordi a gagné")
            P_Ordi = P_Ordi + 1
        break
        
            
    while C_Joueur == "3" :
        if C_Ordi == 1 :
            print("L'ordi a gagné")
            P_Ordi = P_Ordi + 1
            
        elif P_Ordi == 2 :
            print("Vous avez gagné !")
            print("Bravo !")
            P_Joueur = P_Joueur + 1
            
        elif C_Ordi == 3 :
             print("Egalité")
        break 

if P_Joueur > P_Ordi :
    print("You win GG !")
    print("Vous avez", P_Joueur, "points, et l'ordi as", P_Ordi, "points !")
    
if P_Joueur < P_Ordi :
    print("Sorry you lose, try again")
    print("L'ordi as", P_Ordi, "points, et vous avez", P_Joueur, "points !")
elif P_Joueur == P_Ordi :
    print ("draw")
# Out:
# Egalité
# Egalité
# Vous avez gagné !
# Bravo !
# Egalité
# Egalité
# You win GG !
# Vous avez 1 points, et l'ordi as 0 points !

# %%
from random import *

P_Joueur = 0
C_Joueur = 0

P_Ordi = 0
C_Ordi = 0

for i in range (1, 6):
    
    C_Ordi = randint(1, 3)              
    C_Joueur = input("1 : pierre, 2 : papier, 3 : ciseaux ? ") 
    while C_Joueur == "1" :
        if C_Ordi == 1:
            print("Egalité")
        elif C_Ordi == 2 :
            print("L'ordi a gagné")
            P_Ordi = P_Ordi + 1
        elif C_Ordi == 3 :
            print("Vous avez gagné !")
            print("Bravo !")
            P_Joueur = P_Joueur + 1
        break
        
            
    while C_Joueur == "2" :
        if C_Ordi == 1 :
            print("Vous avez gagné !")
            print("Bravo !")
            P_Joueur = P_Joueur + 1
            
        elif C_Ordi == 2 :
               print("Egalité")
                
        elif C_Ordi == 3 :
            print("L'ordi a gagné")
            P_Ordi = P_Ordi + 1
        break
        
            
    while C_Joueur == "3" :
        if C_Ordi == 1 :
            print("L'ordi a gagné")
            P_Ordi = P_Ordi + 1
            
        elif P_Ordi == 2 :
            print("Vous avez gagné !")
            print("Bravo !")
            P_Joueur = P_Joueur + 1
            
        elif C_Ordi == 3 :
             print("Egalité")
        break 

if P_Joueur > P_Ordi :
    print("You win GG !")
    print("Vous avez", P_Joueur, "points, et l'ordi as", P_Ordi, "points !")
    
if P_Joueur < P_Ordi :
    print("Sorry you lose, try again")
    print("L'ordi as", P_Ordi, "points, et vous avez", P_Joueur, "points !")
elif P_Joueur == P_Ordi :
    print ("draw")
# Out:
# Vous avez gagné !
# Bravo !
# L'ordi a gagné
# L'ordi a gagné
# Egalité
# Egalité
# Sorry you lose, try again
# L'ordi as 2 points, et vous avez 1 points !
